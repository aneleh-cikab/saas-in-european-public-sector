# %%
import numpy as np
import pandas as pd
from pandas.core.dtypes.common import pandas_dtype as dtype

import dask.bag as db

import json

# %% [markdown]
# # Reading in and exploring Digiwhist data (available for download from https://opentender.eu/at/download)
# # Downloaded NDJSON version of All data, January 2023

# %%
#read all ndjson files to dask bag

bag = db.read_text('C:/Hertie/Thesis/data-all-ndjson/data-all-*.ndjson', blocksize="200MiB").map(json.loads)

# %%
bag.take(1)
# Out:
# ({'created': '2020-09-18T07:45:00.725379',
#   'modified': '2021-03-05T23:05:24.27887',
#   'metaData': {'opentender': True},
#   'persistentId': 'RO_45fb967156738c42b1adfc64e6f7fc6babdc7314ce8f86c630f1af7db2509b96_8368',
#   'processingOrder': '2019-11-18 13:32:47.55390400',
#   'title': 'TUB NEON FLUORESCENT',
#   'cpvs': [{'code': '31532910-6', 'isMain': True}],
#   'indicators': [{'type': 'INTEGRITY_SINGLE_BID',
#     'status': 'INSUFFICIENT_DATA'},
#    {'type': 'ADMINISTRATIVE_CENTRALIZED_PROCUREMENT',
#     'status': 'INSUFFICIENT_DATA'},
#    {'type': 'INTEGRITY_ADVERTISEMENT_PERIOD',
#     'status': 'CALCULATED',
#     'value': 100},
#    {'type': 'INTEGRITY_DECISION_PERIOD', 'status': 'CALCULATED', 'value': 50},
#    {'type': 'ADMINISTRATIVE_COVERED_BY_GPA', 'status': 'INSUFFICIENT_DATA'},
#    {'type': 'ADMINISTRATIVE_ELECTRONIC_AUCTION',
#     'status': 'INSUFFICIENT_DATA'},
#    {'type': 'ADMINISTRATIVE_FRAMEWORK_AGREEMENT',
#     'status': 'INSUFFICIENT_DATA'},
#    {'type': 'INTEGRITY_NEW_COMPANY', 'status': 'INSUFFICIENT_DATA'},
#    {'type': 'ADMINISTRATIVE_ENGLISH_AS_FOREIGN_LANGUAGE',
#     'status': 'INSUFFICIENT_DATA'},
#    {'type': 'INTEGRITY_CALL_FOR_TENDER_PUBLICATION',
#     'status': 'CALCULATED',
#     'value': 0},
#    {'type': 'INTEGRITY_PROCEDURE_TYPE', 'status': 'CALCULATED', 'value': 100},
#    {'type': 'INTEGRITY_TAX_HAVEN', 'status': 'CALCULATED', 'value': 100},
#    {'type': 'ADMINISTRATIVE_NOTICE_AND_AWARD_DISCREPANCIES',
#     'status': 'INSUFFICIENT_DATA'},
#    {'type': 'TRANSPARENCY_BIDDER_NAME_MISSING',
#     'status': 'CALCULATED',
#     'value': 100},
#    {'type': 'TRANSPARENCY_VALUE_MISSING', 'status': 'CALCULATED', 'value': 0},
#    {'type': 'TRANSPARENCY_MISSING_ELIGIBLE_BID_LANGUAGES',
#     'status': 'UNDEFINED'},
#    {'type': 'TRANSPARENCY_MISSING_ADDRESS_OF_IMPLEMENTATION_NUTS',
#     'status': 'CALCULATED',
#     'value': 0},
#    {'type': 'TRANSPARENCY_MISSING_OR_INCOMPLETE_AWARD_CRITERIA',
#     'status': 'UNDEFINED'},
#    {'type': 'TRANSPARENCY_MISSING_OR_INCOMPLETE_CPVS', 'status': 'UNDEFINED'},
#    {'type': 'TRANSPARENCY_MISSING_OR_INCOMPLETE_DURATION_INFO',
#     'status': 'UNDEFINED'},
#    {'type': 'TRANSPARENCY_MISSING_SELECTION_METHOD', 'status': 'UNDEFINED'},
#    {'type': 'TRANSPARENCY_MISSING_SUBCONTRACTED_INFO',
#     'status': 'CALCULATED',
#     'value': 0},
#    {'type': 'TRANSPARENCY_MISSING_OR_INCOMPLETE_FUNDINGS_INFO',
#     'status': 'UNDEFINED'}],
#   'buyerAssignedId': 'DA0432440',
#   'procedureType': 'OUTRIGHT_AWARD',
#   'nationalProcedureType': 'Cumparare directa',
#   'buyers': [{'processingOrder': '2021-02-10 16:24:38.73065500',
#     'name': 'Liceul Tehnologic "Sfantul Pantelimon"',
#     'address': {'city': 'Bucuresti',
#      'country': 'Romania',
#      'rawAddress': 'Strada: Hambarului, nr. 12A, Sector: 2, Judet: Bucuresti, Localitate: Bucuresti, Cod postal: 021904',
#      'state': 'Bucuresti'},
#     'email': 'liceul_sfpantelimon@yahoo.com',
#     'phone': '+40 212559943',
#     'id': 'RO_body_8056da26471c9fae2c6c43832e67e6e56d42a0e4c98cc92e089805b6550d24a5'}],
#   'publications': [{'source': 'http://data.gov.ro/',
#     'buyerAssignedId': 'DA0432440',
#     'publicationDate': '2009-09-17',
#     'isIncluded': True,
#     'formType': 'CONTRACT_AWARD',
#     'sourceFormType': 'CONTRACT_AWARD'}],
#   'lots': [{'contractSignatureDate': '2009-09-21',
#     'indicators': [{'@class': 'eu.dl.dataaccess.dto.indicator.BasicIndicator',
#       'metaData': {},
#       'type': 'INTEGRITY_SINGLE_BID',
#       'status': 'INSUFFICIENT_DATA'},
#      {'@class': 'eu.dl.dataaccess.dto.indicator.BasicIndicator',
#       'type': 'INTEGRITY_DECISION_PERIOD',
#       'status': 'CALCULATED',
#       'value': 50},
#      {'@class': 'eu.dl.dataaccess.dto.indicator.BasicIndicator',
#       'type': 'INTEGRITY_NEW_COMPANY',
#       'status': 'INSUFFICIENT_DATA'},
#      {'@class': 'eu.dl.dataaccess.dto.indicator.BasicIndicator',
#       'type': 'TRANSPARENCY_BIDDER_NAME_MISSING',
#       'status': 'CALCULATED',
#       'value': 100},
#      {'@class': 'eu.dl.dataaccess.dto.indicator.BasicIndicator',
#       'type': 'TRANSPARENCY_VALUE_MISSING',
#       'status': 'CALCULATED',
#       'value': 0},
#      {'@class': 'eu.dl.dataaccess.dto.indicator.BasicIndicator',
#       'type': 'TRANSPARENCY_MISSING_OR_INCOMPLETE_AWARD_CRITERIA',
#       'status': 'UNDEFINED'},
#      {'@class': 'eu.dl.dataaccess.dto.indicator.BasicIndicator',
#       'type': 'TRANSPARENCY_MISSING_OR_INCOMPLETE_CPVS',
#       'status': 'UNDEFINED'},
#      {'@class': 'eu.dl.dataaccess.dto.indicator.BasicIndicator',
#       'type': 'TRANSPARENCY_MISSING_OR_INCOMPLETE_DURATION_INFO',
#       'status': 'UNDEFINED'},
#      {'@class': 'eu.dl.dataaccess.dto.indicator.BasicIndicator',
#       'type': 'TRANSPARENCY_MISSING_SELECTION_METHOD',
#       'status': 'UNDEFINED'},
#      {'@class': 'eu.dl.dataaccess.dto.indicator.BasicIndicator',
#       'type': 'TRANSPARENCY_MISSING_SUBCONTRACTED_INFO',
#       'status': 'CALCULATED',
#       'value': 0},
#      {'@class': 'eu.dl.dataaccess.dto.indicator.BasicIndicator',
#       'type': 'TRANSPARENCY_MISSING_OR_INCOMPLETE_FUNDINGS_INFO',
#       'status': 'UNDEFINED'},
#      {'@class': 'eu.dl.dataaccess.dto.indicator.BasicIndicator',
#       'metaData': {'bidderGroupId': 'group_RO_body_250383502726ed1005f9598dc87ae6abd9e5e275ee21b0ae91f56023845e4f49'},
#       'type': 'INTEGRITY_TAX_HAVEN',
#       'status': 'CALCULATED',
#       'value': 100}],
#     'status': 'AWARDED',
#     'bids': [{'isWinning': True,
#       'bidders': [{'processingOrder': '2020-07-13 15:38:03.63589900',
#         'name': 'DANI DIVERTIKA S.R.L.',
#         'address': {'city': 'Bucuresti',
#          'country': 'RO',
#          'rawAddress': 'Strada: Soseaua Pantelimon, nr. 255, Sector: 2, Judet: Bucuresti, Localitate: Bucuresti, Cod postal: 030350'},
#         'id': 'RO_body_250383502726ed1005f9598dc87ae6abd9e5e275ee21b0ae91f56023845e4f49'}],
#       'bidId': 'group_RO_tender_dfeadd8a683d2ac4094c1000d7598777c5f2a965_1_1'}],
#     'lotId': 'group_RO_tender_dfeadd8a683d2ac4094c1000d7598777c5f2a965_1'}],
#   'country': 'RO',
#   'groupId': 'group_RO_tender_dfeadd8a683d2ac4094c1000d7598777c5f2a965',
#   'id': 'b6e58cd6-2552-4433-9c03-ab43ffc9e28a',
#   'ot': {'country': 'RO',
#    'scores': [{'type': 'INTEGRITY', 'value': 70, 'status': 'CALCULATED'},
#     {'type': 'TRANSPARENCY', 'value': 25, 'status': 'CALCULATED'},
#     {'type': 'TENDER', 'value': 47.5, 'status': 'CALCULATED'}],
#    'cpv': '31532910',
#    'date': '2009-09-17'}},)

# %%
bag.filter(lambda record: record['cpvs'][0]['code'].startswith("48")).take(1)
# Out:
# ({'created': '2020-09-18T04:11:34.408506',
#   'modified': '2021-03-05T21:08:14.924809',
#   'metaData': {'opentender': True},
#   'persistentId': 'RO_d0818d42bfaa20a7902386f22a16f6a8b7dd9c203c0b5ea3e5f84df4d296716b_9916',
#   'processingOrder': '2019-11-18 13:32:31.38997400',
#   'title': 'SWITCH 8 PORTURI',
#   'cpvs': [{'code': '48219500-1', 'isMain': True}],
#   'indicators': [{'type': 'INTEGRITY_SINGLE_BID',
#     'status': 'INSUFFICIENT_DATA'},
#    {'type': 'ADMINISTRATIVE_CENTRALIZED_PROCUREMENT',
#     'status': 'INSUFFICIENT_DATA'},
#    {'type': 'INTEGRITY_ADVERTISEMENT_PERIOD',
#     'status': 'CALCULATED',
#     'value': 100},
#    {'type': 'INTEGRITY_DECISION_PERIOD', 'status': 'CALCULATED', 'value': 50},
#    {'type': 'ADMINISTRATIVE_COVERED_BY_GPA', 'status': 'INSUFFICIENT_DATA'},
#    {'type': 'ADMINISTRATIVE_ELECTRONIC_AUCTION',
#     'status': 'INSUFFICIENT_DATA'},
#    {'type': 'ADMINISTRATIVE_FRAMEWORK_AGREEMENT',
#     'status': 'INSUFFICIENT_DATA'},
#    {'type': 'INTEGRITY_NEW_COMPANY', 'status': 'INSUFFICIENT_DATA'},
#    {'type': 'ADMINISTRATIVE_ENGLISH_AS_FOREIGN_LANGUAGE',
#     'status': 'INSUFFICIENT_DATA'},
#    {'type': 'INTEGRITY_CALL_FOR_TENDER_PUBLICATION',
#     'status': 'CALCULATED',
#     'value': 0},
#    {'type': 'INTEGRITY_PROCEDURE_TYPE', 'status': 'CALCULATED', 'value': 100},
#    {'type': 'INTEGRITY_TAX_HAVEN', 'status': 'INSUFFICIENT_DATA'},
#    {'type': 'ADMINISTRATIVE_NOTICE_AND_AWARD_DISCREPANCIES',
#     'status': 'INSUFFICIENT_DATA'},
#    {'type': 'TRANSPARENCY_BIDDER_NAME_MISSING',
#     'status': 'CALCULATED',
#     'value': 100},
#    {'type': 'TRANSPARENCY_VALUE_MISSING',
#     'status': 'CALCULATED',
#     'value': 100},
#    {'type': 'TRANSPARENCY_MISSING_ELIGIBLE_BID_LANGUAGES',
#     'status': 'UNDEFINED'},
#    {'type': 'TRANSPARENCY_MISSING_ADDRESS_OF_IMPLEMENTATION_NUTS',
#     'status': 'CALCULATED',
#     'value': 0},
#    {'type': 'TRANSPARENCY_MISSING_OR_INCOMPLETE_AWARD_CRITERIA',
#     'status': 'UNDEFINED'},
#    {'type': 'TRANSPARENCY_MISSING_OR_INCOMPLETE_CPVS', 'status': 'UNDEFINED'},
#    {'type': 'TRANSPARENCY_MISSING_OR_INCOMPLETE_DURATION_INFO',
#     'status': 'UNDEFINED'},
#    {'type': 'TRANSPARENCY_MISSING_SELECTION_METHOD', 'status': 'UNDEFINED'},
#    {'type': 'TRANSPARENCY_MISSING_SUBCONTRACTED_INFO',
#     'status': 'CALCULATED',
#     'value': 0},
#    {'type': 'TRANSPARENCY_MISSING_OR_INCOMPLETE_FUNDINGS_INFO',
#     'status': 'UNDEFINED'}],
#   'buyerAssignedId': 'DA0296406',
#   'procedureType': 'OUTRIGHT_AWARD',
#   'nationalProcedureType': 'Cumparare directa',
#   'size': 'BELOW_THE_THRESHOLD',
#   'buyers': [{'processingOrder': '2020-07-13 15:38:03.00021800',
#     'name': 'TRIBUNALUL SUCEAVA',
#     'id': 'RO_body_9abf55757c2796c5935f5d4729cfd967bc642ff43a5c6cf9a42098e3e76c77f7'}],
#   'publications': [{'source': 'http://data.gov.ro/',
#     'buyerAssignedId': 'DA0296406',
#     'publicationDate': '2009-05-29',
#     'isIncluded': True,
#     'formType': 'CONTRACT_AWARD',
#     'sourceFormType': 'CONTRACT_AWARD'}],
#   'lots': [{'contractSignatureDate': '2009-06-01',
#     'indicators': [{'@class': 'eu.dl.dataaccess.dto.indicator.BasicIndicator',
#       'metaData': {},
#       'type': 'INTEGRITY_SINGLE_BID',
#       'status': 'INSUFFICIENT_DATA'},
#      {'@class': 'eu.dl.dataaccess.dto.indicator.BasicIndicator',
#       'type': 'INTEGRITY_DECISION_PERIOD',
#       'status': 'CALCULATED',
#       'value': 50},
#      {'@class': 'eu.dl.dataaccess.dto.indicator.BasicIndicator',
#       'type': 'INTEGRITY_NEW_COMPANY',
#       'status': 'INSUFFICIENT_DATA'},
#      {'@class': 'eu.dl.dataaccess.dto.indicator.BasicIndicator',
#       'type': 'TRANSPARENCY_BIDDER_NAME_MISSING',
#       'status': 'CALCULATED',
#       'value': 100},
#      {'@class': 'eu.dl.dataaccess.dto.indicator.BasicIndicator',
#       'type': 'TRANSPARENCY_VALUE_MISSING',
#       'status': 'CALCULATED',
#       'value': 100},
#      {'@class': 'eu.dl.dataaccess.dto.indicator.BasicIndicator',
#       'type': 'TRANSPARENCY_MISSING_OR_INCOMPLETE_AWARD_CRITERIA',
#       'status': 'UNDEFINED'},
#      {'@class': 'eu.dl.dataaccess.dto.indicator.BasicIndicator',
#       'type': 'TRANSPARENCY_MISSING_OR_INCOMPLETE_CPVS',
#       'status': 'UNDEFINED'},
#      {'@class': 'eu.dl.dataaccess.dto.indicator.BasicIndicator',
#       'type': 'TRANSPARENCY_MISSING_OR_INCOMPLETE_DURATION_INFO',
#       'status': 'UNDEFINED'},
#      {'@class': 'eu.dl.dataaccess.dto.indicator.BasicIndicator',
#       'type': 'TRANSPARENCY_MISSING_SELECTION_METHOD',
#       'status': 'UNDEFINED'},
#      {'@class': 'eu.dl.dataaccess.dto.indicator.BasicIndicator',
#       'type': 'TRANSPARENCY_MISSING_SUBCONTRACTED_INFO',
#       'status': 'CALCULATED',
#       'value': 0},
#      {'@class': 'eu.dl.dataaccess.dto.indicator.BasicIndicator',
#       'type': 'TRANSPARENCY_MISSING_OR_INCOMPLETE_FUNDINGS_INFO',
#       'status': 'UNDEFINED'},
#      {'@class': 'eu.dl.dataaccess.dto.indicator.BasicIndicator',
#       'type': 'INTEGRITY_TAX_HAVEN',
#       'status': 'INSUFFICIENT_DATA'}],
#     'status': 'AWARDED',
#     'bids': [{'isWinning': True,
#       'bidders': [{'processingOrder': '2020-07-13 15:38:03.84891400',
#         'name': 'ASSIST SOFTWARE S.R.L.',
#         'address': {'city': 'Suceava',
#          'country': 'RO',
#          'rawAddress': 'Strada: Tipografiei, nr. 1, Sector: -, Judet: Suceava, Localitate: Suceava, Cod postal: 720043'},
#         'id': 'RO_body_b3c3d9bddcf69782524ff934cdb7483322879192c61d35f5a191c2281a5bead8'}],
#       'price': {'netAmount': 912,
#        'vat': 19,
#        'currency': 'RON',
#        'netAmountEur': 218.24,
#        'currencyNational': 'RON',
#        'netAmountNational': 912,
#        'publicationDate': '2009-05-29'},
#       'robustPrice': {'netAmount': 912,
#        'vat': 19,
#        'currency': 'RON',
#        'netAmountEur': 218,
#        'currencyNational': 'RON',
#        'netAmountNational': 912,
#        'reliability': 0.5},
#       'bidId': 'group_RO_tender_bab2c7e2e0e9381acb93432b1702d63c34982d08_1_1',
#       'digiwhistPrice': {'netAmount': 218.24,
#        'currency': 'EUR',
#        'netAmountEur': 218.24}}],
#     'lotId': 'group_RO_tender_bab2c7e2e0e9381acb93432b1702d63c34982d08_1'}],
#   'country': 'RO',
#   'groupId': 'group_RO_tender_bab2c7e2e0e9381acb93432b1702d63c34982d08',
#   'digiwhistPrice': {'netAmount': 218.24,
#    'currency': 'EUR',
#    'netAmountEur': 218.24},
#   'id': '79546efa-4b88-40ba-83cd-eb2693f70660',
#   'ot': {'country': 'RO',
#    'scores': [{'type': 'INTEGRITY', 'value': 62.5, 'status': 'CALCULATED'},
#     {'type': 'TRANSPARENCY', 'value': 50, 'status': 'CALCULATED'},
#     {'type': 'TENDER', 'value': 56.25, 'status': 'CALCULATED'}],
#    'cpv': '48219500',
#    'date': '2009-05-29'}},)

# %%
#If using exeption handling, entire rows are passed when a single missing key is encountered.
#This is not the desired behaviour, so I will use the get method instead.

def flatten(record):
    return {
            'persistend_id' : record.get('persistentId', None),    
            'title': record.get('title', None),
            'title_english': record.get('titleEnglish', None),
            'description': record.get('description', None),
            'cpv' : [list.get("code", None) for list in record.get("cpvs", {})],
            'country' : record.get('country', None),
            'price' : record.get('digiwhistPrice', {}).get('netAmountEur', None),
            'cpv_2' : record.get('ot', {}).get('cpv', None),
            'date' : record.get('ot', {}).get('date', None),
            'procedure' : record.get('procedureType', None),
            'size' : record.get('size', None),
            'buyer_type' : [list.get("buyerType", None) for list in record.get("buyers", {})],                                  
            'buyer_activity' : [x for list in record.get("buyers", {}) for x in list.get("mainActivities", {})],
        }

DTYPES = {
     'persistend_id': dtype('O'),
     'title': dtype('string'),
     'title_english': dtype('string'),
     'description': dtype('string'),
     'cpv': dtype('O'),
     'country': dtype('string'),
     'price': dtype('float'),
     'cpv_2' : dtype('O'),
     'date' : dtype('datetime64[ns]'),
     'size' : dtype('O'),
     'procedure' : dtype('string'),
     'size' : dtype('string'),
     'buyer_type' : dtype('string'),
     'buyer_activity' : dtype('O') 
}

# %% [markdown]
# # Filtering digiwhist data:
# # 1. By column cpv_2
# # 2. By column cpv

# %%
# 1. By column cpv_2

#filter rows that have None in cpv_2 column
#df_cpv_code = df_cpv_code[df_cpv_code['cpv_2'].notnull()]

df_1 = (bag.map(flatten)
         .filter(lambda x: x['cpv_2'] is not None)
         .filter(lambda x: x['cpv_2'].startswith('48') or x['cpv_2'].startswith('72'))
         .to_dataframe(meta=DTYPES)
         .compute()
          )

# %%
df_1.tail(10)
# Out:
#                                          persistend_id  \
# 984  PL_560656f510e56287c76098ff594b4795ab0c1b4858f...
# 985  PL_3c40be92c7870f6fc13ba1cad63b6f1d59d6f9c41ad...
# 986  HU_9bf803a6f9ceda65dada21f7e8bf0d643d2ebc14b6e...
# 987  HU_d64989fe15ac6cb9d827a0130420f4e06e9c5219f77...
# 988  PL_98644105c0eacd162932772cd194bf48fde35d4f7ba...
# 989  PL_98b7705ffae33e4c886b1fe20e8f8559451fd32c1dc...
# 990  PL_7cf28203824013eda502c62f77334d8ede73501c7fd...
# 991  PL_66518c26f5b0c019627f386aaa298c441a050eae8ec...
# 992  PL_732ecd399e28302d55b25c780a74e130c7c59a2058f...
# 993  PL_9a85a764caf3346b51c19e779861532d2acd4b8da17...
#
#                                                  title title_english  \
# 984     Dostawa i zainstalowanie sprzętu komputerowego          <NA>
# 985  Dostawa sprzętu komputerowego i oprogramowania...          <NA>
# 986  Az MNB-ben jelenleg működő SAP R/3 4.6C verzió...          <NA>
# 987  Levéltári dokumentumok (minisztertanácsi jegyz...          <NA>
# 988  Dostawa licencji oprogramowania Systemu Biblio...          <NA>
# 989  Postępowanie o udzielenie zamówienia publiczne...          <NA>
# 990  Dostawa i montaż dwóch ekranów LED (Pawilon A-...          <NA>
# 991  Zakup aktualizacji na 12 miesięcy 2009 roku na...          <NA>
# 992  ZAKUP OPROGRAMOWANIA, AKCESORIÓW KOMPUTEROWYCH...          <NA>
# 993  Rozszerzenie oprogramowania INFOMEDICA o kolej...          <NA>
#
#                                            description  \
# 984  Przedmiotem zamówienia jest dostawa i zainstal...
# 985  Przedmiotem zamówienia jest dostawa sprzętu i ...
# 986                                               <NA>
# 987                                               <NA>
# 988  Rozszerzenie licencji na potrzeby istniejącej ...
# 989  Dostawa i instalacja systemu wspomagania organ...
# 990  dostawa i montaż dwóch ekranów LED (Pawilon A-...
# 991  Zakup aktualizacji na 12 miesięcy 2009 roku na...
# 992  oprogramowanie, akceria komputerowe, zestawy k...
# 993  Przedmiotem umowy jest: a) dostawa Oprogramowa...
#
#                                                    cpv country      price  \
# 984                             [302620003, 302332202]      PL   42795.00
# 985                  [302620003, 302311008, 302410000]      PL   71865.00
# 986                                        [722000007]      HU        NaN
# 987                                       [72313000-2]      HU        NaN
# 988                                        [481600007]      PL  135736.00
# 989       [489000007, 453143200, 453153001, 480000008]      PL  155409.00
# 990                                        [302543100]      PL        NaN
# 991                                        [722680001]      PL  126048.00
# 992  [487000000, 302131006, 302313100, 302321201, 3...      PL   44002.00
# 993                                        [302494000]      PL  131147.54
#
#         cpv_2 date                 size                       procedure  \
# 984  48822000  NaT  BELOW_THE_THRESHOLD             APPROACHING_BIDDERS
# 985  48822000  NaT  BELOW_THE_THRESHOLD             APPROACHING_BIDDERS
# 986  72200000  NaT                 <NA>                           OTHER
# 987  72313000  NaT                 <NA>                           OTHER
# 988  48160000  NaT  BELOW_THE_THRESHOLD  NEGOTIATED_WITHOUT_PUBLICATION
# 989  48900000  NaT  BELOW_THE_THRESHOLD                            OPEN
# 990  48813100  NaT  BELOW_THE_THRESHOLD                            OPEN
# 991  72268000  NaT  BELOW_THE_THRESHOLD  NEGOTIATED_WITHOUT_PUBLICATION
# 992  48700000  NaT  BELOW_THE_THRESHOLD                            OPEN
# 993  48442000  NaT  BELOW_THE_THRESHOLD  NEGOTIATED_WITHOUT_PUBLICATION
#
#                  buyer_type                                  buyer_activity
# 984               ['OTHER']                                              []
# 985  ['REGIONAL_AUTHORITY']                                              []
# 986               ['OTHER']  [OTHER, ECONOMIC_AND_FINANCIAL_AFFAIRS, WATER]
# 987               ['OTHER']                                  [OTHER, WATER]
# 988               ['OTHER']                                              []
# 989               ['OTHER']                                              []
# 990         ['PUBLIC_BODY']                                              []
# 991  ['REGIONAL_AUTHORITY']                                              []
# 992               ['OTHER']                                              []
# 993         ['PUBLIC_BODY']                                              []

# %%
len(df_1)
# Out:
# 158105

# %%
# 2. By column cpv
# @Note: Column cpv is a list of cpv codes. To filter on the list, I will create a list of all cpv codes that start with 48 or 72 and then filter on that list.

# read only value on the first position of data/cpv-codes.csv and save as list
cpv_codes = []
with open('../data/cpv-codes.csv', 'r') as f:
    next(f)
    for line in f:
        cpv = line.split(',')[0]
        cpv_codes.append(cpv)

# for cpv in cpv_codes: 
# remove dash and append to list

cpv_codes_nodash = [cpv.replace('-', '') for cpv in cpv_codes]

# for cpv code in cpv_codes:
# remove dash and everything after it and append to list

cpv_codes_short = [cpv.split('-')[0] for cpv in cpv_codes]

# append all lists to one list

cpv_codes_all = cpv_codes + cpv_codes_nodash + cpv_codes_short

# remove duplicates from cpv_codes_all

cpv_codes_all = list(dict.fromkeys(cpv_codes_all))

len(cpv_codes_all)

# %%
df_2 = (bag.map(flatten)
           .filter(lambda x: x['cpv'] is not None)
           .filter(lambda x: np.any(np.in1d(x["cpv"], cpv_codes)))
           .to_dataframe(meta=DTYPES)
           .compute()
        )

# %%
df_2.tail()
# Out:
#                                          persistend_id  \
# 144  EU_d0bba8b9a09b01ff6c93d57a445c18149b4931e8a69...
# 145  EU_a0609a26734d15f24b93d033a0d7c2a19446623ce07...
# 146  EU_a0609a26734d15f24b93d033a0d7c2a19446623ce07...
# 147  EU_a0609a26734d15f24b93d033a0d7c2a19446623ce07...
# 148  HU_d64989fe15ac6cb9d827a0130420f4e06e9c5219f77...
#
#                                                  title title_english  \
# 144                                               <NA>          <NA>
# 145                                               <NA>          <NA>
# 146                                               <NA>          <NA>
# 147                                               <NA>          <NA>
# 148  Levéltári dokumentumok (minisztertanácsi jegyz...          <NA>
#
#     description                                                cpv country  \
# 144        <NA>                                         [72000000]      FR
# 145        <NA>                                         [72000000]      FR
# 146        <NA>                               [72000000, 72521100]      ES
# 147        <NA>  [30200000, 30241000, 50312000, 50312500, 72000...      FR
# 148        <NA>                                       [72313000-2]      HU
#
#           price     cpv_2 date                 size procedure  \
# 144   1662780.0  72000000  NaT  ABOVE_THE_THRESHOLD      OPEN
# 145   2327413.0  72000000  NaT  ABOVE_THE_THRESHOLD      OPEN
# 146  46599940.0  72000000  NaT  ABOVE_THE_THRESHOLD      OPEN
# 147  54300000.0  30200000  NaT  ABOVE_THE_THRESHOLD      OPEN
# 148         NaN  72313000  NaT                 <NA>     OTHER
#
#                  buyer_type                     buyer_activity
# 144  ['NATIONAL_AUTHORITY']                            [OTHER]
# 145  ['NATIONAL_AUTHORITY']   [OTHER, GENERAL_PUBLIC_SERVICES]
# 146  ['REGIONAL_AUTHORITY']  [HEALTH, GENERAL_PUBLIC_SERVICES]
# 147  ['NATIONAL_AUTHORITY']          [GENERAL_PUBLIC_SERVICES]
# 148               ['OTHER']                     [OTHER, WATER]

# %%
# no of rows df_2
len(df_2)
# Out:
# 107541

# %%
# concat rows from df_2 to df_1 and keep only unique rows based on persistent_id, title and description
df = pd.concat([df_1, df_2], ignore_index=True)
df.head()
# Out:
#                                        persistend_id  \
# 0  RO_d0818d42bfaa20a7902386f22a16f6a8b7dd9c203c0...
# 1  RO_beff4a52b9c1e030c5b893d11957ffe7e2414238658...
# 2  RO_37cdc8af7044078a9b7282f60df5baf17432c0c2fc1...
# 3  RO_87fac2096a66de8fead815de15c90f3bbb9985753fb...
# 4  RO_9a2b37224f3370dcc972a4f2a969a2c9dfaa8686178...
#
#                                             title title_english description  \
# 0                                SWITCH 8 PORTURI          <NA>        <NA>
# 1                                  Achizitie soft          <NA>        <NA>
# 2                Bitdefender for File Server 2010          <NA>        <NA>
# 3                   Office Standard 2007 Academic          <NA>        <NA>
# 4  Software antivirus Kaspersky Internet Security          <NA>        <NA>
#
#             cpv country    price     cpv_2       date                 size  \
# 0  [48219500-1]      RO   218.24  48219500 2009-05-29  BELOW_THE_THRESHOLD
# 1  [48517000-5]      RO  1019.20  48517000 2009-05-22  BELOW_THE_THRESHOLD
# 2  [48761000-0]      RO   137.80  48761000 2009-11-23  BELOW_THE_THRESHOLD
# 3  [48900000-7]      RO      NaN  48900000 2009-11-25                 <NA>
# 4  [48761000-0]      RO      NaN  48761000 2009-10-22                 <NA>
#
#         procedure              buyer_type buyer_activity
# 0  OUTRIGHT_AWARD                  [None]             []
# 1  OUTRIGHT_AWARD                  [None]             []
# 2  OUTRIGHT_AWARD  ['REGIONAL_AUTHORITY']    [EDUCATION]
# 3  OUTRIGHT_AWARD                  [None]             []
# 4  OUTRIGHT_AWARD                  [None]             []

# %%
# drop duplicates based on persistent_id, title, description, country, price, cpv_2, date, size, procedure
df = df.drop_duplicates(subset=['persistend_id', 'title', 'description', 'country', 'price', 'cpv_2', 'date', 'size', 'procedure'], keep='first')

# %%
#save df_1 to csv in data folder as digiwhist_1.csv
df_1.to_csv('../data/digiwhist_1.csv', index=False)

#save df_2 to csv in data folder as digiwhist_2.csv
df_2.to_csv('../data/digiwhist_2.csv', index=False)

# save df to csv in data folder as digiwhist.csv
df.to_csv('../data/digiwhist.csv', index=False)

# %% [markdown]
# # Exploring Digiwhist df

# %%
# open digiwhist.csv and save as dataframe
df = pd.read_csv('../data/digiwhist.csv')

# %%
len(df)
# Out:
# 168110

# %%
df.head()
# Out:
#                                        persistend_id  \
# 0  RO_d0818d42bfaa20a7902386f22a16f6a8b7dd9c203c0...
# 1  RO_beff4a52b9c1e030c5b893d11957ffe7e2414238658...
# 2  RO_37cdc8af7044078a9b7282f60df5baf17432c0c2fc1...
# 3  RO_87fac2096a66de8fead815de15c90f3bbb9985753fb...
# 4  RO_9a2b37224f3370dcc972a4f2a969a2c9dfaa8686178...
#
#                                             title title_english description  \
# 0                                SWITCH 8 PORTURI           NaN         NaN
# 1                                  Achizitie soft           NaN         NaN
# 2                Bitdefender for File Server 2010           NaN         NaN
# 3                   Office Standard 2007 Academic           NaN         NaN
# 4  Software antivirus Kaspersky Internet Security           NaN         NaN
#
#               cpv country    price       cpv_2        date  \
# 0  ['48219500-1']      RO   218.24  48219500.0  2009-05-29
# 1  ['48517000-5']      RO  1019.20  48517000.0  2009-05-22
# 2  ['48761000-0']      RO   137.80  48761000.0  2009-11-23
# 3  ['48900000-7']      RO      NaN  48900000.0  2009-11-25
# 4  ['48761000-0']      RO      NaN  48761000.0  2009-10-22
#
#                   size       procedure              buyer_type buyer_activity
# 0  BELOW_THE_THRESHOLD  OUTRIGHT_AWARD                  [None]             []
# 1  BELOW_THE_THRESHOLD  OUTRIGHT_AWARD                  [None]             []
# 2  BELOW_THE_THRESHOLD  OUTRIGHT_AWARD  ['REGIONAL_AUTHORITY']  ['EDUCATION']
# 3                  NaN  OUTRIGHT_AWARD                  [None]             []
# 4                  NaN  OUTRIGHT_AWARD                  [None]             []

# %%
#group by country and frequency
df.groupby('country').size().sort_values(ascending=False)
# Out:
# country
# RO    67558
# PL    17543
# ES    15080
# FR    13836
# DE     5309
# UK     3839
# NO     3601
# CZ     3521
# NL     2563
# HU     2528
# IE     2523
# AT     2313
# LT     2191
# IT     2127
# EE     1771
# HR     1677
# SE     1637
# BE     1467
# LV     1464
# CH     1307
# PT     1182
# GE     1170
# FI     1136
# SI     1042
# BG     1038
# SK     1000
# DK      705
# GR      609
# LU      175
# CY      106
# MT       80
# MK       73
# IS       35
# MD       12
# LI        5
# RS        2
# GI        2
# TR        2
# MG        1
# NP        1
# KE        1
# IN        1
# SD        1
# ET        1
# GF        1
# JP        1
# dtype: int64

# %%
# table that shows a count of rows per country in rows and year from date in columns
df['year'] = pd.DatetimeIndex(df['date']).year
df.groupby(['country', 'year']).size().unstack(fill_value=0)
# Out:
# year     2009.0  2010.0  2011.0  2012.0  2013.0  2014.0  2015.0  2016.0  \
# country
# AT           34      22      29      15      27      25      33      30
# BE          122     105     112     102      74      85      88      85
# BG           72      51      41      48      61      59      55      43
# CH           53      46      39      58      55      39     113      76
# CY           11       8       3       6       7       2       4       5
# CZ          226     225     187     334     398     293     285     184
# DE          282     306     235     229     233     224     280     346
# DK           43      63      47      46      57      50      61      39
# EE          143     146     104     110     116     122     129     140
# ES          458     450     193     280     320     357     473     624
# ET            0       0       0       0       0       0       0       0
# FI           88      68      52      68      58      70      71      79
# FR         1069     996     907     838     784     810     875     755
# GE            0       5     112      95      85      97     109     103
# GF            0       0       0       0       0       0       0       0
# GI            0       0       1       1       0       0       0       0
# GR           60      49      26      23      51      34      18       8
# HR           92      81     100      99     124      79      93     119
# HU          102     120     151     202     277     260     270     178
# IE           94      91      72     105     196     160     166     164
# IN            0       0       0       1       0       0       0       0
# IS            0       1       1       1       1       1       0       5
# IT          236     188     117     114      99     105     120      97
# JP            0       0       0       0       0       0       1       0
# KE            0       0       0       0       0       0       0       0
# LI            0       0       1       0       0       0       0       0
# LT           93     163     185     121     312     251     237     217
# LU            9       3       4       3       7       8      10       9
# LV           26      35      15      22     169     151     177     163
# MD            0       0       0       0       0       0       0       0
# MG            0       0       0       0       0       0       0       0
# MK            1       0       1       3       1       6       6      14
# MT            3       4       2       3       4       5       5       5
# NL          101     103      84     108     163     284     286     271
# NO          202     236     226     223     209     201     200     223
# NP            0       0       0       0       0       0       0       0
# PL         1499    1597    1509    1545    1598    1341    1210     694
# PT           38      41      26      29      39      54      75      72
# RO          627    1136    1696    1693    1795     961    2509    6608
# RS            0       0       0       0       1       0       1       0
# SD            0       0       0       1       0       0       0       0
# SE           72      76      58      80      89     125     126     123
# SI           57      54      36      36      44      36      41      74
# SK           96      60      50     105     112     108      71      44
# TR            0       0       0       0       0       0       0       0
# UK          318     309     341     404     393     406     426     492
#
# year     2017.0  2018.0  2019.0  2020.0  2021.0  2022.0
# country
# AT           30      37     276     464     730     507
# BE           88      98      93      89     128      87
# BG           65      63      78      94     140      96
# CH           99     119     111     148     203     125
# CY            5       8       9       6      10       8
# CZ          128     205     213     189     196     121
# DE          323     415     431     539     599     432
# DK           44      41      52      49      42      24
# EE          109      96      85      86     115      57
# ES          899    1327    2270    2357    2872    1860
# ET            0       0       0       1       0       0
# FI           70      89      90      96     114      71
# FR          845     745     731     672     771     520
# GE          100      91      97      91     122      63
# GF            0       0       0       0       0       1
# GI            0       0       0       0       0       0
# GR            9      17      20      33      20      30
# HR          107     137     176     159     170      86
# HU          239     138      96     132     120      87
# IE          181     213     201     231     262     173
# IN            0       0       0       0       0       0
# IS            3       4       0       6       4       6
# IT           98     102     132     106     133      80
# JP            0       0       0       0       0       0
# KE            0       0       0       0       1       0
# LI            0       0       0       2       0       1
# LT          155      70      78      91     111      72
# LU           14      16      16      26      23      17
# LV          114     108      89     105     126     101
# MD            0       0       0       0       8       4
# MG            0       0       0       1       0       0
# MK            9       7       6       6       9       2
# MT            8      14       5       6       4      11
# NL          242     149     156     194     162     121
# NO          194     217     241     251     279     176
# NP            0       0       0       0       1       0
# PL         1489    1217    1219    1517     389     163
# PT           84     109     138     148     173     118
# RO         8536   12251   12683   12822    1940    1398
# RS            0       0       0       0       0       0
# SD            0       0       0       0       0       0
# SE          123     125     143     147     183     122
# SI          118     103     132     133     119      79
# SK           64      55      45      45      54      39
# TR            0       0       1       1       0       0
# UK          549     615     677     649     575     376

# %%
#change description column of df_cpv_code to lower case
df['description'] = df['description'].str.lower()

# %%
saas = df[df['description'].str.contains('saas') | df['description'].str.contains('software as a service')]

# %%
# table that shows a count of rows per country in rows and year from date in columns
saas.groupby(['country', 'year']).size().unstack(fill_value=0)
# Out:
# year     2009.0  2011.0  2012.0  2013.0  2014.0  2015.0  2016.0  2017.0  \
# country
# AT            0       0       0       0       0       0       0       0
# BE            0       1       1       4       1       0       1       1
# CH            0       0       0       0       1       3       0       1
# CZ            0       0       0       0       1       0       0       0
# DE            0       0       1       0       1       2       2       3
# DK            0       0       0       1       0       0       3       4
# EE            1       2       1       1       1       0       1       0
# ES            0       0       0       0       1       0       2       0
# FI            0       2       1       3       2       3       4       3
# FR            0       5       5       4       6       9       5      13
# HR            0       0       0       0       0       0       0       0
# HU            0       0       0       0       0       0       0       0
# IE            0       0       0       0       0       2       0       0
# IT            0       0       0       0       1       3       1       1
# LV            0       0       0       0       0       0       0       0
# NL            0       4       1       2       4       7       7       7
# NO            0       1       0       2       0       1       2       4
# PL            0       1       0       1       0       0       1       3
# PT            0       0       0       0       1       0       0       1
# RO            0       0       0       0       0       0       0       0
# SE            0       0       0       0       0       1       0       0
# SK            0       0       1       0       0       0       1       0
# UK            0       0       2       2       1       8       6       7
#
# year     2018.0  2019.0  2020.0  2021.0  2022.0
# country
# AT            0       0       2       1       1
# BE            1       1       4       6       2
# CH            2       1       4       5       0
# CZ            0       2       0       1       0
# DE            4       5       7      13       7
# DK            2       2       0       1       3
# EE            0       1       3       1       0
# ES            0       1       2       2       4
# FI           12      12      17      22       9
# FR           15      19      15      13      17
# HR            0       1       1       1       1
# HU            1       0       0       0       0
# IE            3       3       1       7       9
# IT            2       4       3       2       2
# LV            0       0       1       0       0
# NL            5       9      20      19      11
# NO            5       4       4       9       5
# PL            4       2       7       1       0
# PT            0       1       2       0       1
# RO           12       8      14       1       2
# SE            3       4       6       5       2
# SK            0       0       0       0       1
# UK            8      12       9       6      10
