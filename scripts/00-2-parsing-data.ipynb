# %%
# PARSING DATA TO CSV

import glob
import bs4
import csv

# CHANGE PATHS HERE: Add path to the folder where the html files are located.
path_to_html = "C:/Thesis-data/*.html"
path_to_html_trimmed = "C:/Thesis-data\\" # trimmed path for extracting tender ID.  

files=glob.glob(path_to_html) 

for number,file in enumerate(files, 1):

    if number % 1000 == 0:
        print("Now at number: ", number)
    
            
    html = open(file, 'r', encoding="utf-8")
    soup = bs4.BeautifulSoup(html, 'html.parser')
    id = file.replace(path_to_html_trimmed, '').replace('.html', '')
    
    # gtting elements from the soup and saving them as text
    
    try:
        title_1 = soup.select_one('span:-soup-contains("Title")').find_next_sibling("div").text.strip()
    except:
        title_1 = None
    try:
        title_2 = soup.select_one('span:-soup-contains("Title attributed to the contract")').find_next_sibling("div").text.strip()
    except:
        title_2 = None
    title = title_1 if title_1 else title_2

    try:
        cpv_1 = soup.select_one('span:-soup-contains("Main CPV code")').find_next_sibling("div").text.strip()
    except:
        cpv_1 = None
    try:
        cpv_2 = soup.select_one('span:-soup-contains("Common procurement vocabulary (CPV)")').find_next_sibling("div").text.strip()
    except:
        cpv_2 = None
    cpv = cpv_1 if cpv_1 else cpv_2

    try:
        contract_type = soup.select_one('span:-soup-contains("Type of contract")').find_next_sibling("div").text.strip()
    except:
        contract_type = None
    
    try:
        description_1 = soup.select_one('span:-soup-contains("Short description")').find_next_sibling("div").text.strip()
    except:
        description_1 = None
    try:
        description_2 = soup.select_one('span:-soup-contains("Short description of the contract or purchase(s)")').find_next_sibling("div").text.strip()
    except:
        description_2 = None
    try:
        description_3 = soup.select_one('span:-soup-contains("Description of the procurement")').find_next_sibling("div").text.strip()
    except:
        description_3 = None     
    
    if description_1:
        description = description_1
    elif description_2:
        description = description_2
    else:
        description = description_3
    
    try:
        country_1 = soup.select_one('span:-soup-contains("Name and addresses")').find_next_sibling("div")
    except:
        country_1 = None
    try:
        country_2 = soup.select_one('span:-soup-contains("addresses")').find_next_sibling("div")
    except:
        country_2 = None
    country = country_1 if country_1 else country_2
    
    try:
        contracting_authority_type = soup.select_one('span:-soup-contains("Type of the contracting authority")').find_next_sibling("div").text.strip()
    except:
        contracting_authority_type = None
    try:
        contracting_authority_activity = soup.select_one('span:-soup-contains("Main activity")').find_next_sibling("div").text.strip()
    except:
        contracting_authority_activity = None
    
    # Estimated value of the contract is not always in the same place, hence the try-except blocks.

    try:
        value_1 = soup.select_one('span:-soup-contains("Estimated total value")').find_next_sibling("div").text.strip()
    except:
        value_1 = None
    try:
        value_2 = soup.select_one('span:-soup-contains("Total value of the procurement (excluding VAT)")').find_next_sibling("div").text.strip()
    except:
        value_2 = None
    try:
        value_3 = soup.select_one('span:-soup-contains("Total final value of contract")').find_next_sibling("div").text.strip()
    except:
        value_3 = None
    try:
        value_4 = soup.select_one('span:-soup-contains("Total quantity or scope")').find_next_sibling("div").text.strip()
    except:
        value_4 = None
    try:
        value_5 = soup.select_one('span:-soup-contains("II.2.1)")').find_next_sibling("div").text.strip()
    except:
        value_5 = None
    
    if value_1:
        value = value_1
    elif value_2:
        value = value_2
    elif value_3:
        value = value_3
    elif value_4:
        value = value_4
    else:
        value = value_5
    
    try:
        type_of_procedure = soup.select_one('span:-soup-contains("IV.1.1)")').find_next_sibling("div").text.strip()
    except:
        type_of_procedure = None
    try:
        government_procurement_agreement = soup.select_one('span:-soup-contains("Government Procurement Agreement (GPA)")').find_next_sibling("div").text.strip()
    except:
        government_procurement_agreement = None

    
    try:
        framework_agreement_1 = soup.select_one('span:-soup-contains("Information about a framework agreement or a dynamic purchasing system")')
        
        if framework_agreement_1:
            try:
                framework_agreement_1 = framework_agreement_1.find_next_sibling("div").text.strip()
            except:
                framework_agreement_1 = "No" #DIV not found, hence it is not a framework agreement nor DPS
    except:
        framework_agreement_1 = None #span not found, hence the entire line is missing
    
    try:
        framework_agreement_2 = soup.select_one('span:-soup-contains("Information about a public contract, a framework agreement or a dynamic purchasing system (DPS)")')
        if framework_agreement_2:
            try:
                framework_agreement_2 = framework_agreement_2.find_next_sibling("div").text.strip()
            except:
                framework_agreement_2 = "No" #DIV not found, hence it is not a framework agreement nor DPS

    except:
        framework_agreement_2 = None
    
    framework_agreement = framework_agreement_1 if framework_agreement_1 else framework_agreement_2
    

    try:
        notice_dispatch_date = soup.select_one('span:-soup-contains("Date of dispatch of this notice:")').find_next_sibling("div").text.strip()
    except:
        notice_dispatch_date = None
    try:
        application_date = soup.select_one('span:-soup-contains("Time limit for receipt of tenders or requests to participate")').find_next_sibling("div").text.strip()
    except:
        application_date = None
    try:
        tender_opening_date = soup.select_one('span:-soup-contains("Conditions for opening of tenders")').find_next_sibling("div").text.strip()
    except:
        tender_opening_date = None

    # saving data
    with open('../data/parsed_data_new.csv', 'a', newline='', encoding='utf-8') as f:
        writer = csv.writer(f)
        writer.writerow([id, title, cpv, contract_type, description, country, contracting_authority_type, contracting_authority_activity, value, type_of_procedure, 
                 government_procurement_agreement, framework_agreement, notice_dispatch_date, application_date, tender_opening_date])
# Out:
# Now at number:  1000
# Now at number:  2000
# Now at number:  3000
# Now at number:  4000
# Now at number:  5000
# Now at number:  6000
# Now at number:  7000
# Now at number:  8000
# Now at number:  9000
# Now at number:  10000
# Now at number:  11000
# Now at number:  12000
# Now at number:  13000
# Now at number:  14000
# Now at number:  15000
# Now at number:  16000
# Now at number:  17000
# Now at number:  18000
# Now at number:  19000
# Now at number:  20000
# Now at number:  21000
# Now at number:  22000
# Now at number:  23000
# Now at number:  24000
# Now at number:  25000
# Now at number:  26000
# Now at number:  27000
# Now at number:  28000
# Now at number:  29000
# Now at number:  30000
# Now at number:  31000
# Now at number:  32000
# Now at number:  33000
# Now at number:  34000
# Now at number:  35000
# Now at number:  36000
# Now at number:  37000
# Now at number:  38000
# Now at number:  39000
# Now at number:  40000
# Now at number:  41000
# Now at number:  42000
# Now at number:  43000
# Now at number:  44000
# Now at number:  45000
# Now at number:  46000
# Now at number:  47000
# Now at number:  48000
# Now at number:  49000
# Now at number:  50000
# Now at number:  51000
# Now at number:  52000
# Now at number:  53000
# Now at number:  54000
# Now at number:  55000
# Now at number:  56000
# Now at number:  57000
# Now at number:  58000
# Now at number:  59000
# Now at number:  60000
# Now at number:  61000
# Now at number:  62000
# Now at number:  63000
# Now at number:  64000
# Now at number:  65000
# Now at number:  66000
# Now at number:  67000
# Now at number:  68000
# Now at number:  69000
# Now at number:  70000
# Now at number:  71000
# Now at number:  72000
# Now at number:  73000
# Now at number:  74000
# Now at number:  75000
# Now at number:  76000
# Now at number:  77000
# Now at number:  78000
# Now at number:  79000
# Now at number:  80000
# Now at number:  81000
# Now at number:  82000
# Now at number:  83000
# Now at number:  84000
# Now at number:  85000
# Now at number:  86000
# Now at number:  87000
# Now at number:  88000
# Now at number:  89000
# Now at number:  90000
# Now at number:  91000
# Now at number:  92000
# Now at number:  93000
# Now at number:  94000
# Now at number:  95000
# Now at number:  96000
# Now at number:  97000
# Now at number:  98000
# Now at number:  99000
# Now at number:  100000
# Now at number:  101000
# Now at number:  102000
# Now at number:  103000
# Now at number:  104000
# Now at number:  105000
# Now at number:  106000
# Now at number:  107000
# Now at number:  108000
# Now at number:  109000
# Now at number:  110000
# Now at number:  111000
# Now at number:  112000
# Now at number:  113000
# Now at number:  114000
# Now at number:  115000
# Now at number:  116000
# Now at number:  117000
# Now at number:  118000
# Now at number:  119000
# Now at number:  120000
# Now at number:  121000
# Now at number:  122000
# Now at number:  123000
# Now at number:  124000
# Now at number:  125000
# Now at number:  126000
# Now at number:  127000
# Now at number:  128000
# Now at number:  129000
# Now at number:  130000
# Now at number:  131000
# Now at number:  132000
# Now at number:  133000
# Now at number:  134000
# Now at number:  135000
# Now at number:  136000
# Now at number:  137000
# Now at number:  138000
# Now at number:  139000
# Now at number:  140000
# Now at number:  141000
# Now at number:  142000
# Now at number:  143000
# Now at number:  144000
# Now at number:  145000
# Now at number:  146000
# Now at number:  147000
# Now at number:  148000
# Now at number:  149000
# Now at number:  150000
# Now at number:  151000
# Now at number:  152000
# Now at number:  153000
# Now at number:  154000
# Now at number:  155000
# Now at number:  156000
# Now at number:  157000
# Now at number:  158000
# Now at number:  159000
# Now at number:  160000
# Now at number:  161000
# Now at number:  162000
# Now at number:  163000
# Now at number:  164000
# Now at number:  165000
# Now at number:  166000
# Now at number:  167000
# Now at number:  168000
# Now at number:  169000
# Now at number:  170000
# Now at number:  171000
# Now at number:  172000
# Now at number:  173000
# Now at number:  174000
# Now at number:  175000
# Now at number:  176000
# Now at number:  177000
# Now at number:  178000
# Now at number:  179000
# Now at number:  180000
# Now at number:  181000
# Now at number:  182000
# Now at number:  183000
# Now at number:  184000
# Now at number:  185000
# Now at number:  186000
# Now at number:  187000
# Now at number:  188000
# Now at number:  189000
# Now at number:  190000
# Now at number:  191000
# Now at number:  192000
# Now at number:  193000
# Now at number:  194000
# Now at number:  195000
# Now at number:  196000
# Now at number:  197000
# Now at number:  198000
# Now at number:  199000
# Now at number:  200000
# Now at number:  201000
# Now at number:  202000
# Now at number:  203000
# Now at number:  204000
# Now at number:  205000
# Now at number:  206000
# Now at number:  207000
# Now at number:  208000
# Now at number:  209000
# Now at number:  210000
# Now at number:  211000
# Now at number:  212000
# Now at number:  213000
# Now at number:  214000
# Now at number:  215000
# Now at number:  216000
# Now at number:  217000
# Now at number:  218000
# Now at number:  219000
# Now at number:  220000
# Now at number:  221000
# Now at number:  222000
# Now at number:  223000
# Now at number:  224000
# Now at number:  225000
# Now at number:  226000
# Now at number:  227000
# Now at number:  228000
# Now at number:  229000
# Now at number:  230000
# Now at number:  231000
# Now at number:  232000
# Now at number:  233000
# Now at number:  234000
# Now at number:  235000
# Now at number:  236000
# Now at number:  237000
# Now at number:  238000
# Now at number:  239000
# Now at number:  240000
# Now at number:  241000
# Now at number:  242000
# Now at number:  243000
# Now at number:  244000
# Now at number:  245000
# Now at number:  246000
# Now at number:  247000
# Now at number:  248000
# Now at number:  249000
# Now at number:  250000
# Now at number:  251000
# Now at number:  252000
# Now at number:  253000
# Now at number:  254000
# Now at number:  255000
# Now at number:  256000
# Now at number:  257000
# Now at number:  258000
# Now at number:  259000
# Now at number:  260000
# Now at number:  261000
# Now at number:  262000
# Now at number:  263000
# Now at number:  264000
# Now at number:  265000
# Now at number:  266000
# Now at number:  267000
# Now at number:  268000
# Now at number:  269000
# Now at number:  270000
# Now at number:  271000
# Now at number:  272000
# Now at number:  273000
# Now at number:  274000
# Now at number:  275000
# Now at number:  276000
# Now at number:  277000
# Now at number:  278000
# Now at number:  279000
# Now at number:  280000
# Now at number:  281000
# Now at number:  282000
# Now at number:  283000
# Now at number:  284000
# Now at number:  285000
# Now at number:  286000
# Now at number:  287000
# Now at number:  288000
# Now at number:  289000
# Now at number:  290000
# Now at number:  291000
# Now at number:  292000
# Now at number:  293000
# Now at number:  294000
# Now at number:  295000
# Now at number:  296000
# Now at number:  297000
# Now at number:  298000
# Now at number:  299000
# Now at number:  300000
# Now at number:  301000
# Now at number:  302000
# Now at number:  303000
# Now at number:  304000
# Now at number:  305000
# Now at number:  306000
# Now at number:  307000
# Now at number:  308000
# Now at number:  309000
# Now at number:  310000
# Now at number:  311000
# Now at number:  312000
# Now at number:  313000
# Now at number:  314000
# Now at number:  315000
# Now at number:  316000
# Now at number:  317000
# Now at number:  318000
# Now at number:  319000
# Now at number:  320000
# Now at number:  321000
# Now at number:  322000
# Now at number:  323000
# Now at number:  324000
# Now at number:  325000
# Now at number:  326000
# Now at number:  327000
# Now at number:  328000
# Now at number:  329000
# Now at number:  330000
# Now at number:  331000
# Now at number:  332000
# Now at number:  333000
# Now at number:  334000
# Now at number:  335000
# Now at number:  336000
# Now at number:  337000
# Now at number:  338000
# Now at number:  339000
# Now at number:  340000
# Now at number:  341000
# Now at number:  342000
# Now at number:  343000
# Now at number:  344000
# Now at number:  345000
# Now at number:  346000
# Now at number:  347000
# Now at number:  348000
# Now at number:  349000
